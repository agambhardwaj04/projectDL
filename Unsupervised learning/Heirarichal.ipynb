# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.datasets import load_iris

# %%
data = load_iris()
x = pd.DataFrame(data.data, columns=data.feature_names)
y = data.target

# %%
linked = linkage(x,method='ward')
plt.figure(figsize=(10,6))
dendrogram(linked)
plt.title('Heirarichal. Clustering')
plt.xlabel("Sample Index")
plt.ylabel("Distance")
plt.show()

# %%
sil_score = []
range_n_clusters = range(2,11)
for n_clusters in range_n_clusters:
  model = AgglomerativeClustering(n_clusters=n_clusters)
  cluster_labels = model.fit_predict(x)
  silhouette_average = silhouette_score(x, cluster_labels)
  sil_score.append(silhouette_average)
  print(f"For n_clusters={n_clusters},silhouette score is {silhouette_average:.4f}")
# Out:
# For n_clusters=2,silhouette score is 0.6867
# For n_clusters=3,silhouette score is 0.5543
# For n_clusters=4,silhouette score is 0.4890
# For n_clusters=5,silhouette score is 0.4844
# For n_clusters=6,silhouette score is 0.3592
# For n_clusters=7,silhouette score is 0.3422
# For n_clusters=8,silhouette score is 0.3436
# For n_clusters=9,silhouette score is 0.3305
# For n_clusters=10,silhouette score is 0.2925

# %%
model = AgglomerativeClustering(n_clusters=2)
cluster_labels = model.fit_predict(x)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=x.iloc[:,0],y=x.iloc[:,1],hue=cluster_labels,palette='viridis')
plt.legend(title='Cluster')
plt.show()
